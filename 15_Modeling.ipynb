# %%
# imports and loading clean data
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt

from IPython.display import display, Markdown

from modules.lv_utils import load_households, load_voters
from modules.ms1_utils import clean_df, show_vote_rate_and_summary, two_sample_perm_test_diff_frac_votes
from modules.ms1_utils import get_two_sample_ns, plot_hist_vote_rate_vs_field

# load the data
households = load_households('data_clean/20180725_fullset_households_district3.csv')
voters = load_voters('data_clean/20180725_fullset_voters_district3.csv')
elections = pd.read_csv('data_clean/20180621_election_data.csv')

# a couple of constants
outcols = ['votes_s0','elec_n0','rate_r0','votes_s1','elec_n1','rate_r1','emp_diff','perm_p']

# %%
print(voters.columns[:50])
print(voters.columns[50:])
print(households.columns)
elections.columns
# Out:
# Index(['Vid', 'Abbr', 'Precinct', 'PrecinctSub', 'Party', 'PartyMain',
#        'RegDate', 'PAV', 'RegDateOriginal', 'E6_110816', 'E5_060716',
#        'E4_110414', 'E3_060314', 'E2_110612', 'E1_060512', 'District',
#        'VScore', 'VScorePos', 'VScorePct', 'BirthYear',
#        'OldestInHouseBirthYear', 'IsOldestInHouse', 'havePhone',
#        'BirthPlaceState', 'BirthPlaceStateRegion', 'BirthPlaceCountry',
#        'BirthPlaceCountryRegion', 'Gender', 'sameMailAddress', 'MailCountry',
#        'isApt', 'Zip', 'StreetType', 'EmailProvider', 'E5_060716BT',
#        'E1_060512BT', 'Hid', 'cHid', 'E34_nVotesPos', 'E34_nVotes',
#        'E34_nVotesPct', 'E56_nVotesPos', 'E56_nVotes', 'E56_nVotesPct',
#        'E78_nVotesPos', 'E78_nVotes', 'E78_nVotesPct', 'E12_nVotesPos',
#        'E12_nVotes', 'E12_nVotesPct'],
#       dtype='object')
# Index(['E14_nVotesPos', 'E14_nVotes', 'E14_nVotesPct', 'E16_nVotesPos',
#        'E16_nVotes', 'E16_nVotesPct', 'Eap_nVotesPos', 'Eap_nVotes',
#        'Eap_nVotesPct', 'Eag_nVotesPos', 'Eag_nVotes', 'Eag_nVotesPct',
#        'E6_nVotesPos', 'E6_nVotes', 'E6_nVotesPct', 'E5_nVotesPos',
#        'E5_nVotes', 'E5_nVotesPct', 'E4_nVotesPos', 'E4_nVotes',
#        'E4_nVotesPct', 'E3_nVotesPos', 'E3_nVotes', 'E3_nVotesPct',
#        'E2_nVotesPos', 'E2_nVotes', 'E2_nVotesPct', 'E1_nVotesPos',
#        'E1_nVotes', 'E1_nVotesPct', 'E1_GndTth', 'E2_GndTth', 'E3_GndTth',
#        'E4_GndTth', 'E5_GndTth', 'E6_GndTth', 'nVotersInHH', 'PAVCode',
#        'nPAVInHH', 'HasParty', 'nAffInHH', 'isDEM', 'isREP', 'isNPP',
#        'nDEMInHH', 'nREPInHH', 'nNPPInHH', 'E34_nVotesPosInHH',
#        'E34_nVotesInHH', 'E34_nVotesPctInHH', 'E56_nVotesPosInHH',
#        'E56_nVotesInHH', 'E56_nVotesPctInHH', 'E78_nVotesPosInHH',
#        'E78_nVotesInHH', 'E78_nVotesPctInHH', 'E12_nVotesPosInHH',
#        'E12_nVotesInHH', 'E12_nVotesPctInHH', 'E14_nVotesPosInHH',
#        'E14_nVotesInHH', 'E14_nVotesPctInHH', 'E16_nVotesPosInHH',
#        'E16_nVotesInHH', 'E16_nVotesPctInHH', 'Eap_nVotesPosInHH',
#        'Eap_nVotesInHH', 'Eap_nVotesPctInHH', 'Eag_nVotesPosInHH',
#        'Eag_nVotesInHH', 'Eag_nVotesPctInHH', 'E1_nVotesPosInHH',
#        'E1_nVotesInHH', 'E1_nVotesPctInHH', 'E2_nVotesPosInHH',
#        'E2_nVotesInHH', 'E2_nVotesPctInHH', 'E3_nVotesPosInHH',
#        'E3_nVotesInHH', 'E3_nVotesPctInHH', 'E4_nVotesPosInHH',
#        'E4_nVotesInHH', 'E4_nVotesPctInHH', 'E5_nVotesPosInHH',
#        'E5_nVotesInHH', 'E5_nVotesPctInHH', 'E6_nVotesPosInHH',
#        'E6_nVotesInHH', 'E6_nVotesPctInHH', 'nVScorePosInHH', 'nVScoreInHH',
#        'nVScorePctInHH', 'CityArea', 'PartiesInHH', 'mostAfflsInHH',
#        'mixedAfflsInHH', 'allAffInHH', 'uniformAffInHH'],
#       dtype='object')
# Index(['Hid', 'StreetType', 'Zip', 'Precinct', 'PrecinctSub', 'District',
#        'CityArea', 'isApt', 'cHid', 'nVoters', 'nAff', 'nPAVs', 'nDEMs',
#        'nREPs', 'nNPPs', 'nVScorePos', 'nVScore', 'nVScorePct',
#        'E34_nVotesPos', 'E34_nVotes', 'E34_nVotesPct', 'E56_nVotesPos',
#        'E56_nVotes', 'E56_nVotesPct', 'E78_nVotesPos', 'E78_nVotes',
#        'E78_nVotesPct', 'E12_nVotesPos', 'E12_nVotes', 'E12_nVotesPct',
#        'E14_nVotesPos', 'E14_nVotes', 'E14_nVotesPct', 'E16_nVotesPos',
#        'E16_nVotes', 'E16_nVotesPct', 'Eap_nVotesPos', 'Eap_nVotes',
#        'Eap_nVotesPct', 'Eag_nVotesPos', 'Eag_nVotes', 'Eag_nVotesPct',
#        'E1_nVotesPos', 'E1_nVotes', 'E1_nVotesPct', 'E2_nVotesPos',
#        'E2_nVotes', 'E2_nVotesPct', 'E3_nVotesPos', 'E3_nVotes',
#        'E3_nVotesPct', 'E4_nVotesPos', 'E4_nVotes', 'E4_nVotesPct',
#        'E5_nVotesPos', 'E5_nVotes', 'E5_nVotesPct', 'E6_nVotesPos',
#        'E6_nVotes', 'E6_nVotesPct', 'PartiesInHH', 'mostAffls', 'mixedAffls',
#        'allAff', 'uniformAff'],
#       dtype='object')
# Index(['elections', 'dates', 'cycle', 'etype', 'president', 'us_senate_maj',
#        'us_repre_maj', 'ca_governor', 'ca_lt_govnor', 'ca_senate_maj',
#        'ca_assembly_maj'],
#       dtype='object')

# %%
households.head()
# Out:
#    Hid StreetType    Zip  Precinct  PrecinctSub  District         CityArea  \
# 0    0         DR  94536    832400            0         3      Centerville
# 1    1     PL/TER  94538    832910            0         3      Centerville
# 2    2        CMN  94538    832620            2         3      Centerville
# 3    3     PL/TER  94538    832910            0         3      Centerville
# 4    4     PL/TER  94536    835410            0         3  Downtown / BART
#
#    isApt  cHid  nVoters     ...      E5_nVotes  E5_nVotesPct  E6_nVotesPos  \
# 0  False     0        2     ...              0      0.000000             1
# 1  False     1        3     ...              1      0.333333             3
# 2  False     2        3     ...              3      1.000000             3
# 3  False     3        2     ...              2      1.000000             2
# 4  False     4        4     ...              3      0.750000             4
#
#    E6_nVotes  E6_nVotesPct      PartiesInHH  mostAffls  mixedAffls  allAff  \
# 0          0          0.00          DEM NPP        DEM       False   False
# 1          3          1.00      REP REP NPP        REP       False   False
# 2          3          1.00      DEM DEM DEM        DEM       False    True
# 3          2          1.00          DEM DEM        DEM       False    True
# 4          3          0.75  DEM DEM DEM DEM        DEM       False    True
#
#    uniformAff
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#
# [5 rows x 65 columns]

# %%
households.iloc[:5,:10]
# Out:
#    Hid StreetType    Zip  Precinct  PrecinctSub  District         CityArea  \
# 0    0         DR  94536    832400            0         3      Centerville
# 1    1     PL/TER  94538    832910            0         3      Centerville
# 2    2        CMN  94538    832620            2         3      Centerville
# 3    3     PL/TER  94538    832910            0         3      Centerville
# 4    4     PL/TER  94536    835410            0         3  Downtown / BART
#
#    isApt  cHid  nVoters
# 0  False     0        2
# 1  False     1        3
# 2  False     2        3
# 3  False     3        2
# 4  False     4        4

# %%
voters.head()
# Out:
#    Vid  Abbr  Precinct  PrecinctSub Party PartyMain    RegDate PAV  \
# 0    0    82    832400            0   DEM       DEM 1992-10-05   Y
# 1    1    82    832910            0   DEM       DEM 2012-11-06   Y
# 2    2    12    832900            0   DEM       DEM 2012-11-06   Y
# 3    3    99    832710            0   NPP       NPP 2016-09-15   N
# 4    4   111    832210            1   DEM       DEM 2018-02-13   Y
#
#   RegDateOriginal E6_110816       ...       E6_nVotesPctInHH nVScorePosInHH  \
# 0      1992-10-05         A       ...                    1.0        33.0189
# 1      2012-10-26         A       ...                    0.8        33.5069
# 2      1980-07-25         A       ...                    1.0        32.0157
# 3      2016-09-15         N       ...                    0.0        22.0126
# 4      2018-02-13                 ...                   -1.0         0.0000
#
#   nVScoreInHH nVScorePctInHH     CityArea              PartiesInHH  \
# 0     33.0189       1.000000  Centerville              DEM NPP NPP
# 1     20.8044       0.620899  Centerville  DEM NPP NPP NPP NPP DEM
# 2     25.6097       0.799911  Centerville              DEM DEM DEM
# 3      0.0000       0.000000  Centerville                  NPP NPP
# 4      0.0000      -1.000000  Centerville                      DEM
#
#    mostAfflsInHH  mixedAfflsInHH  allAffInHH  uniformAffInHH
# 0            DEM           False       False           False
# 1            DEM           False       False           False
# 2            DEM           False        True            True
# 3            NPP           False       False            True
# 4            DEM           False        True            True
#
# [5 rows x 148 columns]

# %%
elections.head()
# Out:
#    elections       dates cycle    etype president  us_senate_maj  \
# 0  E8_110618  2018-11-06  Cong  General       REP              4
# 1  E7_060518  2018-06-05  Cong  Primary       REP              4
# 2  E6_110816  2016-11-08  Pres  General       DEM             10
# 3  E5_060716  2016-06-07  Pres  Primary       DEM             10
# 4  E4_110414  2014-11-04  Cong  General       DEM             -8
#
#    us_repre_maj ca_governor ca_lt_govnor  ca_senate_maj  ca_assembly_maj
# 0            42         DEM          DEM            -13              -28
# 1            42         DEM          DEM            -13              -28
# 2            60         DEM          DEM            -13              -24
# 3            58         DEM          DEM            -13              -24
# 4            34         DEM          DEM            -13              -31
